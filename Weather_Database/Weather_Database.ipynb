# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tome
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | bani walid
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 1 | newport
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | cardston
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | codrington
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | denpasar
# Processing Record 16 of Set 1 | homer
# Processing Record 17 of Set 1 | orchard homes
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | sturgeon falls
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | rumoi
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | leningradskiy
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | santa fe
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | hokitika
# Processing Record 36 of Set 1 | bud
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | muros
# Processing Record 39 of Set 1 | grafton
# Processing Record 40 of Set 1 | talaya
# Processing Record 41 of Set 1 | zeya
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | carauari
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | roma
# Processing Record 47 of Set 1 | pemangkat
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | taranagar
# Processing Record 3 of Set 2 | necochea
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | qurayyat
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | lar
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | hambantota
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | byron bay
# Processing Record 13 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 2 | carahue
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | trabzon
# Processing Record 19 of Set 2 | otake
# Processing Record 20 of Set 2 | belinskiy
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | anadyr
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | aklavik
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | quang ngai
# Processing Record 28 of Set 2 | dunedin
# Processing Record 29 of Set 2 | zheleznodorozhnyy
# Processing Record 30 of Set 2 | tallahassee
# Processing Record 31 of Set 2 | bemidji
# Processing Record 32 of Set 2 | rikitea
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | los llanos de aridane
# Processing Record 35 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 36 of Set 2 | yulara
# Processing Record 37 of Set 2 | sarakhs
# Processing Record 38 of Set 2 | batagay
# Processing Record 39 of Set 2 | geraldton
# Processing Record 40 of Set 2 | kiama
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | mugango
# Processing Record 45 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 47 of Set 2 | tripoli
# Processing Record 48 of Set 2 | mokhotlong
# Processing Record 49 of Set 2 | kahului
# Processing Record 50 of Set 2 | altus
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | hobyo
# Processing Record 5 of Set 3 | shakawe
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | ukiah
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | iracoubo
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | noumea
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | padang
# Processing Record 17 of Set 3 | sibolga
# Processing Record 18 of Set 3 | asau
# Processing Record 19 of Set 3 | lagoa
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | saint-augustin
# Processing Record 22 of Set 3 | constitucion
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | vardo
# Processing Record 25 of Set 3 | nikolayevsk-na-amure
# Processing Record 26 of Set 3 | deputatskiy
# Processing Record 27 of Set 3 | hirara
# Processing Record 28 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | vanimo
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | khurba
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 3 | curitibanos
# Processing Record 37 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | saint anthony
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | erzin
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | longyearbyen
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | mae sai
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | lorengau
# Processing Record 1 of Set 4 | batagay-alyta
# Processing Record 2 of Set 4 | solnechnyy
# Processing Record 3 of Set 4 | upington
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | plettenberg bay
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | havre-saint-pierre
# Processing Record 9 of Set 4 | bahia de caraquez
# Processing Record 10 of Set 4 | srednekolymsk
# Processing Record 11 of Set 4 | katangli
# Processing Record 12 of Set 4 | rafai
# Processing Record 13 of Set 4 | saint-pierre
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | caxias
# Processing Record 16 of Set 4 | aripuana
# Processing Record 17 of Set 4 | kalmunai
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | novyy urengoy
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | harper
# Processing Record 23 of Set 4 | sokoni
# Processing Record 24 of Set 4 | beloha
# Processing Record 25 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | mari-turek
# Processing Record 27 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 4 | bandar-e lengeh
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | milton
# Processing Record 31 of Set 4 | kolyshley
# Processing Record 32 of Set 4 | mackenzie
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | volokonovka
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | champerico
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | kieta
# Processing Record 39 of Set 4 | halifax
# Processing Record 40 of Set 4 | seoul
# Processing Record 41 of Set 4 | tatarsk
# Processing Record 42 of Set 4 | grand gaube
# Processing Record 43 of Set 4 | san cristobal
# Processing Record 44 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | banda aceh
# Processing Record 46 of Set 4 | santa maria
# Processing Record 47 of Set 4 | ostrovnoy
# Processing Record 48 of Set 4 | ucluelet
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | oriental
# Processing Record 1 of Set 5 | mahibadhoo
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | wakkanai
# Processing Record 4 of Set 5 | wewak
# Processing Record 5 of Set 5 | progreso
# Processing Record 6 of Set 5 | nagamangala
# Processing Record 7 of Set 5 | pingliang
# Processing Record 8 of Set 5 | barrow
# Processing Record 9 of Set 5 | zyryanka
# Processing Record 10 of Set 5 | junction city
# Processing Record 11 of Set 5 | caravelas
# Processing Record 12 of Set 5 | souillac
# Processing Record 13 of Set 5 | mercedes
# Processing Record 14 of Set 5 | labuhan
# Processing Record 15 of Set 5 | buraydah
# Processing Record 16 of Set 5 | shu
# Processing Record 17 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-francois
# Processing Record 19 of Set 5 | sistranda
# Processing Record 20 of Set 5 | mackay
# Processing Record 21 of Set 5 | tchollire
# Processing Record 22 of Set 5 | charters towers
# Processing Record 23 of Set 5 | povenets
# Processing Record 24 of Set 5 | henties bay
# Processing Record 25 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 5 | kaspiyskiy
# Processing Record 27 of Set 5 | gladstone
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 5 | verkhnyaya inta
# Processing Record 31 of Set 5 | makakilo city
# Processing Record 32 of Set 5 | san juan
# Processing Record 33 of Set 5 | boralday
# Processing Record 34 of Set 5 | tucurui
# Processing Record 35 of Set 5 | toora-khem
# Processing Record 36 of Set 5 | atambua
# Processing Record 37 of Set 5 | vila franca do campo
# Processing Record 38 of Set 5 | sansai
# City not found. Skipping...
# Processing Record 39 of Set 5 | mogadishu
# Processing Record 40 of Set 5 | arona
# Processing Record 41 of Set 5 | garoua
# Processing Record 42 of Set 5 | krasnoarmeysk
# Processing Record 43 of Set 5 | kattivakkam
# Processing Record 44 of Set 5 | namatanai
# Processing Record 45 of Set 5 | sakakah
# Processing Record 46 of Set 5 | saint-joseph
# Processing Record 47 of Set 5 | san andres
# Processing Record 48 of Set 5 | amparafaravola
# Processing Record 49 of Set 5 | methoni
# Processing Record 50 of Set 5 | richards bay
# Processing Record 1 of Set 6 | port elizabeth
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 6 | pochutla
# Processing Record 5 of Set 6 | muromtsevo
# Processing Record 6 of Set 6 | anyang
# Processing Record 7 of Set 6 | skibbereen
# Processing Record 8 of Set 6 | brae
# Processing Record 9 of Set 6 | jalu
# Processing Record 10 of Set 6 | angoche
# Processing Record 11 of Set 6 | teguldet
# Processing Record 12 of Set 6 | gamboma
# Processing Record 13 of Set 6 | thinadhoo
# Processing Record 14 of Set 6 | valkeala
# Processing Record 15 of Set 6 | derzhavinsk
# Processing Record 16 of Set 6 | omboue
# Processing Record 17 of Set 6 | morada nova
# Processing Record 18 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | kutum
# Processing Record 20 of Set 6 | yar-sale
# Processing Record 21 of Set 6 | namibe
# Processing Record 22 of Set 6 | ibra
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | pangnirtung
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | joao camara
# Processing Record 27 of Set 6 | kilrush
# Processing Record 28 of Set 6 | tiksi
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | abrau-dyurso
# Processing Record 31 of Set 6 | santa teresita
# Processing Record 32 of Set 6 | haines junction
# Processing Record 33 of Set 6 | oliveira
# Processing Record 34 of Set 6 | virginia beach
# Processing Record 35 of Set 6 | malanje
# Processing Record 36 of Set 6 | aguimes
# Processing Record 37 of Set 6 | havelock
# Processing Record 38 of Set 6 | gallup
# Processing Record 39 of Set 6 | khorinsk
# Processing Record 40 of Set 6 | faya
# Processing Record 41 of Set 6 | sambava
# Processing Record 42 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 6 | tautira
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | lakhipur
# Processing Record 46 of Set 6 | pangai
# Processing Record 47 of Set 6 | umm kaddadah
# Processing Record 48 of Set 6 | tabory
# Processing Record 49 of Set 6 | morondava
# Processing Record 50 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 7 | srivardhan
# Processing Record 2 of Set 7 | vestmannaeyjar
# Processing Record 3 of Set 7 | chuy
# Processing Record 4 of Set 7 | sangmelima
# Processing Record 5 of Set 7 | mehamn
# Processing Record 6 of Set 7 | iqaluit
# Processing Record 7 of Set 7 | plavsk
# Processing Record 8 of Set 7 | vao
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | kibaya
# Processing Record 11 of Set 7 | sabancuy
# Processing Record 12 of Set 7 | pauri
# Processing Record 13 of Set 7 | pueblo
# Processing Record 14 of Set 7 | malko tarnovo
# Processing Record 15 of Set 7 | baringo
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | fare
# Processing Record 18 of Set 7 | nurota
# Processing Record 19 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 7 | natal
# Processing Record 21 of Set 7 | along
# Processing Record 22 of Set 7 | hofn
# Processing Record 23 of Set 7 | salinopolis
# Processing Record 24 of Set 7 | kondopoga
# Processing Record 25 of Set 7 | semey
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | mandera
# Processing Record 28 of Set 7 | houma
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | high rock
# Processing Record 31 of Set 7 | winthrop
# Processing Record 32 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 7 | gashua
# Processing Record 34 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 7 | burnie
# Processing Record 36 of Set 7 | spearfish
# Processing Record 37 of Set 7 | lachute
# Processing Record 38 of Set 7 | urumqi
# Processing Record 39 of Set 7 | fortuna
# Processing Record 40 of Set 7 | ixtapa
# Processing Record 41 of Set 7 | comodoro rivadavia
# Processing Record 42 of Set 7 | coquimbo
# Processing Record 43 of Set 7 | asyut
# Processing Record 44 of Set 7 | ndele
# Processing Record 45 of Set 7 | grootfontein
# Processing Record 46 of Set 7 | luau
# Processing Record 47 of Set 7 | sorland
# Processing Record 48 of Set 7 | pucara
# Processing Record 49 of Set 7 | torbay
# Processing Record 50 of Set 7 | puerto cabezas
# Processing Record 1 of Set 8 | dzhebariki-khaya
# Processing Record 2 of Set 8 | spodnja idrija
# Processing Record 3 of Set 8 | talara
# Processing Record 4 of Set 8 | farafangana
# Processing Record 5 of Set 8 | vega de alatorre
# Processing Record 6 of Set 8 | bubaque
# Processing Record 7 of Set 8 | manokwari
# Processing Record 8 of Set 8 | honiara
# Processing Record 9 of Set 8 | san policarpo
# Processing Record 10 of Set 8 | nouakchott
# Processing Record 11 of Set 8 | bulgan
# Processing Record 12 of Set 8 | nelson bay
# Processing Record 13 of Set 8 | westport
# Processing Record 14 of Set 8 | sweetwater
# Processing Record 15 of Set 8 | kavali
# Processing Record 16 of Set 8 | smidovich
# Processing Record 17 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 8 | lagos
# Processing Record 19 of Set 8 | san patricio
# Processing Record 20 of Set 8 | potosi
# Processing Record 21 of Set 8 | carnarvon
# Processing Record 22 of Set 8 | naze
# Processing Record 23 of Set 8 | keflavik
# Processing Record 24 of Set 8 | maragogi
# Processing Record 25 of Set 8 | vila velha
# Processing Record 26 of Set 8 | san luis
# Processing Record 27 of Set 8 | bitkine
# Processing Record 28 of Set 8 | swan hill
# Processing Record 29 of Set 8 | kasiri
# Processing Record 30 of Set 8 | meulaboh
# Processing Record 31 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 8 | merrill
# Processing Record 33 of Set 8 | palembang
# Processing Record 34 of Set 8 | kelamangalam
# Processing Record 35 of Set 8 | oum hadjer
# Processing Record 36 of Set 8 | shangrao
# Processing Record 37 of Set 8 | chapais
# Processing Record 38 of Set 8 | vagamo
# Processing Record 39 of Set 8 | hervey bay
# Processing Record 40 of Set 8 | mouzakion
# City not found. Skipping...
# Processing Record 41 of Set 8 | carutapera
# Processing Record 42 of Set 8 | neuquen
# Processing Record 43 of Set 8 | kabrai
# Processing Record 44 of Set 8 | kota kinabalu
# Processing Record 45 of Set 8 | qaanaaq
# Processing Record 46 of Set 8 | pingxiang
# Processing Record 47 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 8 | manzhouli
# Processing Record 49 of Set 8 | shingu
# Processing Record 50 of Set 8 | sindor
# Processing Record 1 of Set 9 | uvalde
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | leninskoye
# Processing Record 4 of Set 9 | komsomolskiy
# Processing Record 5 of Set 9 | buckeye
# Processing Record 6 of Set 9 | sur
# Processing Record 7 of Set 9 | nagato
# Processing Record 8 of Set 9 | butte
# Processing Record 9 of Set 9 | villa bruzual
# Processing Record 10 of Set 9 | onega
# Processing Record 11 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 9 | sao felix do xingu
# Processing Record 13 of Set 9 | san jose
# Processing Record 14 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 9 | mocuba
# Processing Record 16 of Set 9 | conceicao do araguaia
# Processing Record 17 of Set 9 | shitanjing
# Processing Record 18 of Set 9 | edd
# Processing Record 19 of Set 9 | joao pinheiro
# Processing Record 20 of Set 9 | port augusta
# Processing Record 21 of Set 9 | portland
# Processing Record 22 of Set 9 | nizhniy kuranakh
# Processing Record 23 of Set 9 | kanungu
# Processing Record 24 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 9 | bakaly
# Processing Record 26 of Set 9 | catuday
# Processing Record 27 of Set 9 | ayagoz
# Processing Record 28 of Set 9 | vestmanna
# Processing Record 29 of Set 9 | gasa
# Processing Record 30 of Set 9 | paamiut
# Processing Record 31 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 9 | akdepe
# Processing Record 33 of Set 9 | kirakira
# Processing Record 34 of Set 9 | praia da vitoria
# Processing Record 35 of Set 9 | puerto escondido
# Processing Record 36 of Set 9 | kloulklubed
# Processing Record 37 of Set 9 | manica
# Processing Record 38 of Set 9 | broome
# Processing Record 39 of Set 9 | fuzhou
# Processing Record 40 of Set 9 | berlevag
# Processing Record 41 of Set 9 | sol-iletsk
# Processing Record 42 of Set 9 | coihaique
# Processing Record 43 of Set 9 | tessalit
# Processing Record 44 of Set 9 | atar
# Processing Record 45 of Set 9 | harlingen
# Processing Record 46 of Set 9 | cairns
# Processing Record 47 of Set 9 | egvekinot
# Processing Record 48 of Set 9 | itoigawa
# Processing Record 49 of Set 9 | laguna
# Processing Record 50 of Set 9 | labytnangi
# Processing Record 1 of Set 10 | jiaocheng
# Processing Record 2 of Set 10 | rio rancho
# Processing Record 3 of Set 10 | korla
# Processing Record 4 of Set 10 | qaqortoq
# Processing Record 5 of Set 10 | benguela
# Processing Record 6 of Set 10 | sao jose da coroa grande
# Processing Record 7 of Set 10 | mucurapo
# Processing Record 8 of Set 10 | morro bay
# Processing Record 9 of Set 10 | taltal
# Processing Record 10 of Set 10 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 11 of Set 10 | igarka
# Processing Record 12 of Set 10 | ambalavao
# Processing Record 13 of Set 10 | sabang
# Processing Record 14 of Set 10 | poum
# Processing Record 15 of Set 10 | quatre cocos
# Processing Record 16 of Set 10 | kailua
# Processing Record 17 of Set 10 | moji das cruzes
# City not found. Skipping...
# Processing Record 18 of Set 10 | boda
# Processing Record 19 of Set 10 | buchanan
# Processing Record 20 of Set 10 | cedar city
# Processing Record 21 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 10 | lebu
# Processing Record 23 of Set 10 | sira
# Processing Record 24 of Set 10 | thunder bay
# Processing Record 25 of Set 10 | el limon
# Processing Record 26 of Set 10 | sarangani
# Processing Record 27 of Set 10 | mount isa
# Processing Record 28 of Set 10 | koszalin
# Processing Record 29 of Set 10 | mahdalynivka
# Processing Record 30 of Set 10 | borger
# Processing Record 31 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 10 | oistins
# Processing Record 33 of Set 10 | kandrian
# Processing Record 34 of Set 10 | delano
# Processing Record 35 of Set 10 | samana
# Processing Record 36 of Set 10 | sovetskiy
# Processing Record 37 of Set 10 | bardsir
# Processing Record 38 of Set 10 | cerkezkoy
# Processing Record 39 of Set 10 | siva
# Processing Record 40 of Set 10 | elko
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 10 | pundaguitan
# Processing Record 44 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 10 | xuddur
# Processing Record 46 of Set 10 | moranbah
# Processing Record 47 of Set 10 | hay river
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | bouna
# Processing Record 50 of Set 10 | huarmey
# Processing Record 1 of Set 11 | pevek
# Processing Record 2 of Set 11 | bonavista
# Processing Record 3 of Set 11 | los negros
# Processing Record 4 of Set 11 | sedalia
# Processing Record 5 of Set 11 | kendari
# Processing Record 6 of Set 11 | auki
# Processing Record 7 of Set 11 | goteborg
# City not found. Skipping...
# Processing Record 8 of Set 11 | tilichiki
# Processing Record 9 of Set 11 | coahuayana
# Processing Record 10 of Set 11 | suntar
# Processing Record 11 of Set 11 | muli
# Processing Record 12 of Set 11 | nouadhibou
# Processing Record 13 of Set 11 | bouloupari
# Processing Record 14 of Set 11 | qandala
# Processing Record 15 of Set 11 | mezen
# Processing Record 16 of Set 11 | cassilandia
# Processing Record 17 of Set 11 | adrar
# Processing Record 18 of Set 11 | livingstonia
# Processing Record 19 of Set 11 | bossangoa
# Processing Record 20 of Set 11 | dalhousie
# Processing Record 21 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 11 | sept-iles
# Processing Record 23 of Set 11 | vieux fort
# Processing Record 24 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 11 | cordoba
# Processing Record 27 of Set 11 | teya
# Processing Record 28 of Set 11 | whitehorse
# Processing Record 29 of Set 11 | christchurch
# Processing Record 30 of Set 11 | kralendijk
# Processing Record 31 of Set 11 | naryan-mar
# Processing Record 32 of Set 11 | jipijapa
# Processing Record 33 of Set 11 | zhangye
# Processing Record 34 of Set 11 | celestun
# Processing Record 35 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 11 | ahipara
# Processing Record 37 of Set 11 | sayat
# Processing Record 38 of Set 11 | valdepenas
# Processing Record 39 of Set 11 | vilhena
# Processing Record 40 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 11 | boa vista
# Processing Record 42 of Set 11 | jerez
# Processing Record 43 of Set 11 | west richland
# Processing Record 44 of Set 11 | bireun
# Processing Record 45 of Set 11 | sorong
# Processing Record 46 of Set 11 | ler
# Processing Record 47 of Set 11 | luderitz
# Processing Record 48 of Set 11 | kem
# Processing Record 49 of Set 11 | sao geraldo do araguaia
# Processing Record 50 of Set 11 | slave lake
# Processing Record 1 of Set 12 | fort smith
# Processing Record 2 of Set 12 | north bend
# Processing Record 3 of Set 12 | verkhnevilyuysk
# Processing Record 4 of Set 12 | hongjiang
# Processing Record 5 of Set 12 | mazagao
# Processing Record 6 of Set 12 | crowley
# Processing Record 7 of Set 12 | phan thiet
# Processing Record 8 of Set 12 | stubbekobing
# Processing Record 9 of Set 12 | dagua
# Processing Record 10 of Set 12 | tibiri
# Processing Record 11 of Set 12 | oranjemund
# Processing Record 12 of Set 12 | werda
# Processing Record 13 of Set 12 | svetlaya
# Processing Record 14 of Set 12 | chlorakas
# Processing Record 15 of Set 12 | tongzi
# Processing Record 16 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 17 of Set 12 | xudat
# Processing Record 18 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 12 | winslow
# Processing Record 20 of Set 12 | barras
# Processing Record 21 of Set 12 | san jeronimo
# Processing Record 22 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 23 of Set 12 | barsovo
# Processing Record 24 of Set 12 | chor
# Processing Record 25 of Set 12 | burgeo
# Processing Record 26 of Set 12 | castanos
# Processing Record 27 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 12 | avera
# Processing Record 29 of Set 12 | ossora
# Processing Record 30 of Set 12 | huilong
# Processing Record 31 of Set 12 | giyani
# Processing Record 32 of Set 12 | yondo
# Processing Record 33 of Set 12 | basco
# Processing Record 34 of Set 12 | pervomayskiy
# Processing Record 35 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 36 of Set 12 | roald
# Processing Record 37 of Set 12 | apt
# Processing Record 38 of Set 12 | greymouth
# Processing Record 39 of Set 12 | port shepstone
# Processing Record 40 of Set 12 | miri
# Processing Record 41 of Set 12 | prado
# Processing Record 42 of Set 12 | mangrol
# Processing Record 43 of Set 12 | manuk mangkaw
# Processing Record 44 of Set 12 | rawson
# Processing Record 45 of Set 12 | lukovetskiy
# Processing Record 46 of Set 12 | tukrah
# Processing Record 47 of Set 12 | lakhnadon
# Processing Record 48 of Set 12 | rabo de peixe
# Processing Record 49 of Set 12 | mpika
# Processing Record 50 of Set 12 | labuan
# Processing Record 1 of Set 13 | morant bay
# Processing Record 2 of Set 13 | mount gambier
# Processing Record 3 of Set 13 | salamiyah
# Processing Record 4 of Set 13 | campina grande do sul
# Processing Record 5 of Set 13 | sinnamary
# Processing Record 6 of Set 13 | poronaysk
# Processing Record 7 of Set 13 | hauterive
# Processing Record 8 of Set 13 | mpongwe
# Processing Record 9 of Set 13 | lardos
# Processing Record 10 of Set 13 | severobaykalsk
# Processing Record 11 of Set 13 | yanam
# Processing Record 12 of Set 13 | price
# Processing Record 13 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 13 | kidal
# Processing Record 16 of Set 13 | doha
# Processing Record 17 of Set 13 | miles city
# Processing Record 18 of Set 13 | jabinyanah
# Processing Record 19 of Set 13 | dire dawa
# Processing Record 20 of Set 13 | balaipungut
# Processing Record 21 of Set 13 | belmonte
# Processing Record 22 of Set 13 | nabire
# Processing Record 23 of Set 13 | wanaka
# Processing Record 24 of Set 13 | manado
# Processing Record 25 of Set 13 | utuado
# Processing Record 26 of Set 13 | puerto carreno
# Processing Record 27 of Set 13 | nanakuli
# Processing Record 28 of Set 13 | palana
# Processing Record 29 of Set 13 | bhuban
# Processing Record 30 of Set 13 | birao
# Processing Record 31 of Set 13 | moose factory
# Processing Record 32 of Set 13 | port-gentil
# Processing Record 33 of Set 13 | walvis bay
# Processing Record 34 of Set 13 | portobelo
# Processing Record 35 of Set 13 | flinders
# Processing Record 36 of Set 13 | doka
# Processing Record 37 of Set 13 | lages
# Processing Record 38 of Set 13 | san quintin
# Processing Record 39 of Set 13 | viseu
# Processing Record 40 of Set 13 | ouesso
# Processing Record 41 of Set 13 | riyadh
# Processing Record 42 of Set 13 | mbekenyera
# Processing Record 43 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 44 of Set 13 | imbituba
# Processing Record 45 of Set 13 | merauke
# Processing Record 46 of Set 13 | arman
# Processing Record 47 of Set 13 | mazamari
# Processing Record 48 of Set 13 | anuradhapura
# Processing Record 49 of Set 13 | hovd
# Processing Record 50 of Set 13 | mafinga
# Processing Record 1 of Set 14 | odienne
# Processing Record 2 of Set 14 | le port
# Processing Record 3 of Set 14 | vigrestad
# Processing Record 4 of Set 14 | ajdabiya
# Processing Record 5 of Set 14 | aquiraz
# Processing Record 6 of Set 14 | stockerau
# Processing Record 7 of Set 14 | aswan
# Processing Record 8 of Set 14 | shaunavon
# Processing Record 9 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 14 | ermoupolis
# Processing Record 12 of Set 14 | leh
# Processing Record 13 of Set 14 | oriximina
# Processing Record 14 of Set 14 | biak
# Processing Record 15 of Set 14 | amapa
# Processing Record 16 of Set 14 | mullovka
# Processing Record 17 of Set 14 | acapulco
# Processing Record 18 of Set 14 | saint-leu
# Processing Record 19 of Set 14 | tadine
# Processing Record 20 of Set 14 | novaya lyalya
# Processing Record 21 of Set 14 | wahpeton
# Processing Record 22 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 14 | mattru
# Processing Record 24 of Set 14 | jiamusi
# Processing Record 25 of Set 14 | strezhevoy
# Processing Record 26 of Set 14 | intipuca
# Processing Record 27 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 28 of Set 14 | galveston
# Processing Record 29 of Set 14 | crown point
# Processing Record 30 of Set 14 | atherton
# Processing Record 31 of Set 14 | sao sebastiao
# Processing Record 32 of Set 14 | port hedland
# Processing Record 33 of Set 14 | ialibu
# Processing Record 34 of Set 14 | pecos
# Processing Record 35 of Set 14 | coracora
# Processing Record 36 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 14 | kununurra
# Processing Record 38 of Set 14 | kohima
# Processing Record 39 of Set 14 | muncar
# Processing Record 40 of Set 14 | bestobe
# Processing Record 41 of Set 14 | oussouye
# Processing Record 42 of Set 14 | gulu
# Processing Record 43 of Set 14 | mangai
# Processing Record 44 of Set 14 | curuca
# Processing Record 45 of Set 14 | garachine
# Processing Record 46 of Set 14 | ambulu
# Processing Record 47 of Set 14 | viedma
# Processing Record 48 of Set 14 | fez
# Processing Record 49 of Set 14 | cotonou
# Processing Record 50 of Set 14 | dolores
# Processing Record 1 of Set 15 | nikita
# Processing Record 2 of Set 15 | birnin kebbi
# Processing Record 3 of Set 15 | ust-kan
# Processing Record 4 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 15 | okha
# Processing Record 6 of Set 15 | chunskiy
# Processing Record 7 of Set 15 | uyo
# Processing Record 8 of Set 15 | mana
# Processing Record 9 of Set 15 | olinda
# Processing Record 10 of Set 15 | lasa
# Processing Record 11 of Set 15 | vallenar
# Processing Record 12 of Set 15 | prince rupert
# Processing Record 13 of Set 15 | nisia floresta
# Processing Record 14 of Set 15 | lodwar
# Processing Record 15 of Set 15 | guarapari
# Processing Record 16 of Set 15 | sarankhola
# Processing Record 17 of Set 15 | cardenas
# Processing Record 18 of Set 15 | moroto
# Processing Record 19 of Set 15 | klyuchi
# Processing Record 20 of Set 15 | belaya gora
# Processing Record 21 of Set 15 | skibotn
# Processing Record 22 of Set 15 | zhezkazgan
# Processing Record 23 of Set 15 | bayir
# Processing Record 24 of Set 15 | takoradi
# Processing Record 25 of Set 15 | erenhot
# Processing Record 26 of Set 15 | charleston
# Processing Record 27 of Set 15 | vaitape
# Processing Record 28 of Set 15 | shahrud
# Processing Record 29 of Set 15 | esso
# Processing Record 30 of Set 15 | alexandria
# Processing Record 31 of Set 15 | kenai
# Processing Record 32 of Set 15 | karmaskaly
# Processing Record 33 of Set 15 | guararema
# Processing Record 34 of Set 15 | nemuro
# Processing Record 35 of Set 15 | ternate
# Processing Record 36 of Set 15 | aketi
# Processing Record 37 of Set 15 | chibuto
# Processing Record 38 of Set 15 | brignoles
# Processing Record 39 of Set 15 | jurado
# Processing Record 40 of Set 15 | maniitsoq
# Processing Record 41 of Set 15 | mabopane
# Processing Record 42 of Set 15 | ampanihy
# Processing Record 43 of Set 15 | siniscola
# Processing Record 44 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 15 | roura
# Processing Record 46 of Set 15 | bandarbeyla
# Processing Record 47 of Set 15 | ingham
# Processing Record 48 of Set 15 | gotsu
# Processing Record 49 of Set 15 | santo domingo
# Processing Record 50 of Set 15 | panguna
# Processing Record 1 of Set 16 | pandan
# Processing Record 2 of Set 16 | karaton
# Processing Record 3 of Set 16 | dharmavaram
# Processing Record 4 of Set 16 | andevoranto
# City not found. Skipping...
# Processing Record 5 of Set 16 | tartagal
# Processing Record 6 of Set 16 | palmer
# Processing Record 7 of Set 16 | abu samrah
# Processing Record 8 of Set 16 | tura
# Processing Record 9 of Set 16 | inongo
# Processing Record 10 of Set 16 | port lincoln
# Processing Record 11 of Set 16 | porto seguro
# Processing Record 12 of Set 16 | karratha
# Processing Record 13 of Set 16 | aosta
# Processing Record 14 of Set 16 | abu zabad
# Processing Record 15 of Set 16 | beringovskiy
# Processing Record 16 of Set 16 | piscu
# Processing Record 17 of Set 16 | jumla
# Processing Record 18 of Set 16 | paita
# Processing Record 19 of Set 16 | itoman
# Processing Record 20 of Set 16 | jatiroto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                       Tome -36.6167  -72.9500     47.12        79
# 1                     Kodiak  57.7900 -152.4072     44.76        98
# 2                 Bani Walid  31.7566   13.9942     66.34        72
# 3                 Chokurdakh  70.6333  147.9167     62.10        27
# 4  Petropavlovsk-Kamchatskiy  53.0452  158.6483     52.39        54
# 5                    Newport  51.5877   -2.9984     55.53        82
# 6               Puerto Ayora  -0.7393  -90.3518     73.54        88
# 7                   Cardston  49.2000 -113.3019     59.04        47
# 8                  Mahebourg -20.4081   57.7000     74.25        82
# 9                  Grindavik  63.8424  -22.4338     46.87       100
#
#    Cloudiness  Wind Speed Country   Current Description
# 0          34        5.32      CL      scattered clouds
# 1         100        2.80      US       overcast clouds
# 2          64        7.65      LY         broken clouds
# 3          11       14.38      RU            few clouds
# 4          20       10.94      RU            few clouds
# 5           2        6.91      GB             clear sky
# 6          13        5.01      EC            few clouds
# 7          39        8.10      CA      scattered clouds
# 8          15        7.05      MU            few clouds
# 9          90       33.13      IS  heavy intensity rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df [new_column_order]
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                       Tome      CL -36.6167  -72.9500     47.12        79
# 1                     Kodiak      US  57.7900 -152.4072     44.76        98
# 2                 Bani Walid      LY  31.7566   13.9942     66.34        72
# 3                 Chokurdakh      RU  70.6333  147.9167     62.10        27
# 4  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     52.39        54
# 5                    Newport      GB  51.5877   -2.9984     55.53        82
# 6               Puerto Ayora      EC  -0.7393  -90.3518     73.54        88
# 7                   Cardston      CA  49.2000 -113.3019     59.04        47
# 8                  Mahebourg      MU -20.4081   57.7000     74.25        82
# 9                  Grindavik      IS  63.8424  -22.4338     46.87       100
#
#    Cloudiness  Wind Speed   Current Description
# 0          34        5.32      scattered clouds
# 1         100        2.80       overcast clouds
# 2          64        7.65         broken clouds
# 3          11       14.38            few clouds
# 4          20       10.94            few clouds
# 5           2        6.91             clear sky
# 6          13        5.01            few clouds
# 7          39        8.10      scattered clouds
# 8          15        7.05            few clouds
# 9          90       33.13  heavy intensity rain

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/16478/OneDrive/Desktop/Data BootCamp/Module 6/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
